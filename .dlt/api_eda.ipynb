# %% [markdown]
# # EDA on jobtech API
#
# - arbetsförmedlingen API

# %%
import requests
import json


url = 'https://jobsearch.api.jobtechdev.se'
url_for_search = f"{url}/search"


def _get_ads(params):
    headers = {'accept': 'application/json'}
    response = requests.get(url_for_search, headers=headers, params=params)
    response.raise_for_status()  # check for http errors
    return json.loads(response.content.decode('utf8'))


def example_search_return_number_of_hits(query):
    # limit: 0 means no ads, just a value of how many ads were found.
    search_params = {'q': query, 'limit': 0}
    json_response = _get_ads(search_params)
    number_of_hits = json_response['total']['value']
    print(f"\nNumber of hits = {number_of_hits}")


def example_search_loop_through_hits(query):
    # limit = 100 is the max number of hits that can be returned.
    # If there are more (which you find with ['total']['value'] in the json response)
    # you have to use offset and multiple requests to get all ads.
    search_params = {'q': query, 'limit': 100}
    json_response = _get_ads(search_params)
    hits = json_response['hits']
    for hit in hits:
        print(f"{hit['headline']}, {hit['employer']['name']}")


if __name__ == '__main__':
    query = 'vård'
    example_search_loop_through_hits(query)
    example_search_return_number_of_hits(query)
# Out:
# LÄRARE Vård och omsorg GKC, Gnosjö kommun
# Timvikarier till Vård och Omsorg, Västerås kommun
# Extrajobb inom vård och omsorg, Nordmalings kommun
# Avdelningschef inom vård och Omsorg, Arvika kommun
# Vikarier till Vård och Omsorg, Säffle kommun
# Timvikarier Vård & Stöd Bemanningscentralen, Eda kommun
# Timvikarier – Vård och omsorg, Järfälla kommun
# Timvikariat inom vård och omsorg, Piteå kommun
# Timvikarie till Vård och omsorg, FALKÖPINGS KOMMUN
# Timvikarier inom vård och omsorg, Vännäs kommun
# Timvikarie till Vård och omsorg, Tjörns kommun
# Timvikarier till vård och omsorg, Arboga kommun
# Undersköterska/Vårdare till Örnsköldsgårdens vård och omsorgsboende, ÖRNSKÖLDSVIKS KOMMUN
# Timvikarier till Vård och omsorg, Gläntan, Enköpings kommun
# Timvikariat inom stöd, vård och omsorg, Linköpings kommun
# Undersköterska till Rosenbacken vård och omsorgsboende, ÖRNSKÖLDSVIKS KOMMUN
# Förändringsledare Effektiv och nära vård 2030, Heby kommun
# Capio Vård för hemlösa söker allmänläkare, Capio Sverige AB
# Enhetschef till myndigheten vård och omsorg, Tomelilla kommun
# Vikarie inom vård och omsorg 2024, Marks kommun
# Intresseanmälan timvikarie till vård och omsorg, Borlänge kommun
# Spontanansökan: Medarbetare inom vård och omsorg, Hultsfreds kommun
# Intresseanmälan: Vikarier till vård och omsorg, Rättviks kommun
# Enhetschef till Myndighetsutövning inom Vård och Omsorg, Vårgårda kommun
# Områdesledare till Regional Vård och Läkemedelsprocess (RVLP), REGION STOCKHOLM
# Specialistläkare till palliativ vård och ASIH, Kristianstad, REGION SKÅNE
# Behörig yrkeslärare vård och omsorg - Örebro, AU Utbildning AB
# Timvikariat och vikariat inom vård och omsorg, VÄXJÖ KOMMUN
# Undersköterskor St Knut och Aspen vård och omsorgsboende, VELLINGE KOMMUN
# Undersköterska till avd. 131 och nationell högspecialiserad vård, REGION STOCKHOLM
# Sjuksköterska till poolen Vård och omsorgsboende Väster 1, Örebro kommun
# Sjuksköterska till palliativ vård och ASIH i Hässleholm, REGION SKÅNE
# Politiskt sakkunnig inom socialpolitik, vård och omsorg mm, Miljöpartiet de Gröna
# Sjuksköterska med vårdledaruppdrag till avdelningen för postoperativ vård, REGION STOCKHOLM
# Legitimerad yrkeslärare med behörighet i Vård och omsorg, Abf Göteborg Vuxenutbildning AB
# Intresseanmälan timvikariat inom vård och omsorg -  Bemanningscentrum, Kinda kommun
# Timavlönade inom vård och omsorg, kök eller lokalvård , Halmstads kommun
# Sommarvikarier inom vård och omsorg och inom funktionsstöd, Örebro kommun
# Universitetslektor i vårdvetenskap med inriktning mot psykiatrisk vård, Uppsala Universitet
# Erfaren sjuksköterska till avdelningen för postoperativ vård i Solna, REGION STOCKHOLM
# Sjuksköterska till avd.131 och nationell högspecialiserad vård för vuxna, REGION STOCKHOLM
# ST-läkare till VO intensiv- och perioperativ vård i Malmö, REGION SKÅNE
# Driven och kreativ enhetschef sökes till Vård och Omsorgsboende!, Uddevalla kommun
# Specialistläkare till specialiserad palliativ vård och ASIH i Ängelholm, REGION SKÅNE
# Specialistläkare till specialiserad palliativ vård och ASIH i Ängelholm, REGION SKÅNE
# Vi söker Undersköterskor till Vik hemtjänst, Vård och omsorg, Arvika kommun
# Intresseanmälan timanställning inom vård och omsorg i Östersunds kommun, Östersunds kommun
# Erfaren sjuksköterska till avdelningen för postoperativ vård i Solna, REGION STOCKHOLM
# Erfaren veterinär med intresse för avancerad vård & natur, Svenska Veterinärgruppen Holding AB
# Legitimerade läkare till VO intensiv och perioperativ vård i Lund, REGION SKÅNE
# Praktiska gymnasiet i Karlstad söker yrkeslärare i Vård och Omsorg, Praktiska Sverige AB
# Sektorschef - Bli en del av ledningen på Gryning Vård, Gryning Vård AB
# Sektorschef - Bli en del av ledningen på Gryning Vård, Gryning Vård AB
# Är du vår nya ledare för myndighet vård och omsorg?, Hultsfreds kommun
# Undersköterskor till anestesi på VO intensiv- och perioperativ vård i Lund, REGION SKÅNE
# Nu söker vi dig arbetsterapeut som vill skapa framtidens digifysiska vård!, Arthro Therapeutics AB
# Nu söker vi dig arbetsterapeut som vill skapa framtidens digifysiska vård!, Arthro Therapeutics AB
# Vikarier inom vård och omsorg inom kiruna C och östra kommundelen, Kiruna kommun
# Jobba flexibelt – bli timvikarie inom Vård & Omsorg hos Vetlanda Kommun!, Vetlanda kommun
# Mölndals stad söker dig som vill arbeta som timvikarie inom vård & omsorg!, Mölndals kommun
# Timvikarie till Äldreomsorg inom hemtjänst och särskilt boende i Högsby kom, Högsby kommun
# Specialistläkare i lungmedicin till Lungonkologiskt centrum, REGION STOCKHOLM
# Legitimerad läkare, VÄSTRA GÖTALANDSREGIONEN
# Undersköterska till Psykiatrisk högintensivvårdsavdelning och Akutmottagnin, REGION SKÅNE
# Sjuksköterska till Sandbyhovsgatan 4, Norrköpings kommun
# Interimschef sökes till IVO i Stockholm!, Jurek Recruitment & Consulting AB
# Undersköterska till urologi- och kirurgiavdelning, VÄSTRA GÖTALANDSREGIONEN
# Skolsköterska 20%, Klara E AB
# Undersköterska till hemtjänsten Hölö/Vårdinge , Södertälje kommun
# Är du Vårdcentralen Nyhems nästa avdelningschef?, REGION HALLAND
# Fysioterapeut till Vårdcentralen Laxen i Ängelholm, REGION SKÅNE
# Undersköterska till akutmottagningen, Mora, REGION DALARNA
# Vikarierande stödassistent till Get Johannas gruppbostad, Avesta kommun
# Specialistläkare till Ögonmottagning i Trelleborg, REGION SKÅNE
# Operationssjuksköterska dagtid Barnoperation, Huddinge, REGION STOCKHOLM
# Sjuksköterskeexamen januari 2025? Välkommen till HAKUT!, REGION STOCKHOLM
# Personlig Assistent (vid behov) till kille i Stenhagen, Meet a Group international AB
# Undersköterskor till hemtjänsten i Hede, Härjedalens kommun
# Personlig assistent, vikarie, sökes till Tyresö., Vår Omtanke Sverige AB
# Undersköterskor till Kirurgisk kortvårdsavdelning i Lund, REGION SKÅNE
# Demenssamordnare till Värnamo kommun, Värnamo kommun
# Undersköterska till Björklinge hemvård utanför Uppsala, Forenede Care AB
# Yrkeslärare till BF/VO 50%, Landskrona kommun
# Sjuksköterska sökes till neonatal hemsjukvård Solna, REGION STOCKHOLM
# Avdelningschef, Morö Backe Hälsocentral, Primärvården Nord Skellefteå, REGION VÄSTERBOTTEN
# Undersköterska till Dagverksamhet Enebacken, Åkersberga, norra Stockholm., Forenede Care AB
# Familjeläkarna söker sjuksköterska till ASIH Västerort, Familjeläkarna i Saltsjöbaden AB
# Sjuksköterska till Vårberg Geriatrik, Capio Sverige AB
# Avdelningschef sökes till Kvälls- och helgmottagningen, Halmstad, REGION HALLAND
# Personlig Assistent (vid behov) till kille i Stenhagen, Olivia Personlig Assistans AB
# Distriktssköterska/Barnsjuksköterska BVC, REGION UPPSALA
# Vi söker ny sjuksköterska då en av våra kollegor snart går i pension, VÄSTRA GÖTALANDSREGIONEN
# Undersköterska/skötare Akut och bedömningsmottagning, REGION VÄSTERBOTTEN
# Planerare till Hemtjänst Bjärnum/Vittsjö, Hässleholms kommun
# Rättspsykiatrin söker samordnare dagtid till avdelning 32 o 33 i Säter, REGION DALARNA
# Undersköterska med stort intresse för akut psykiatri till Resursteamet!, REGION STOCKHOLM
# Verksamhetschef för Område Bild- och funktionsmedicin, REGION JÄMTLAND HÄRJEDALEN
# Bemanningsassistent till Lungmedicin, Solna, REGION STOCKHOLM
# Samordnare till boendestöd Stockholm, Collega Arbetsliv AB
# Chaufför med CE-behörighet till bulktransporter, Lbc - Frakt i Värmland AB
#
# Number of hits = 2395
